# %%
text = "The sequel, Yes, Prime Minister, ran from 1986 to 1988. In total there were 38 episodes, of which all but one lasted half an hour. Almost all episodes ended with a variation of the title of the series spoken as the answer to a question posed by the same character, Jim Hacker. Several episodes were adapted for BBC Radio, and a stage play was produced in 2010, the latter leading to a new television series on UKTV Gold in 2013."

# %%
text
# Out:
# 'The sequel, Yes, Prime Minister, ran from 1986 to 1988. In total there were 38 episodes, of which all but one lasted half an hour. Almost all episodes ended with a variation of the title of the series spoken as the answer to a question posed by the same character, Jim Hacker. Several episodes were adapted for BBC Radio, and a stage play was produced in 2010, the latter leading to a new television series on UKTV Gold in 2013.'

# %%
import spacy

# %%
nlp = spacy.load('en_core_web_sm')

# %%
doc = nlp(text)

# %%
doc
# Out:
# The sequel, Yes, Prime Minister, ran from 1986 to 1988. In total there were 38 episodes, of which all but one lasted half an hour. Almost all episodes ended with a variation of the title of the series spoken as the answer to a question posed by the same character, Jim Hacker. Several episodes were adapted for BBC Radio, and a stage play was produced in 2010, the latter leading to a new television series on UKTV Gold in 2013.

# %%
for token in doc:
    print('"' + token.text + '"')
# Out:
# "The"
# "sequel"
# ","
# "Yes"
# ","
# "Prime"
# "Minister"
# ","
# "ran"
# "from"
# "1986"
# "to"
# "1988"
# "."
# "In"
# "total"
# "there"
# "were"
# "38"
# "episodes"
# ","
# "of"
# "which"
# "all"
# "but"
# "one"
# "lasted"
# "half"
# "an"
# "hour"
# "."
# "Almost"
# "all"
# "episodes"
# "ended"
# "with"
# "a"
# "variation"
# "of"
# "the"
# "title"
# "of"
# "the"
# "series"
# "spoken"
# "as"
# "the"
# "answer"
# "to"
# "a"
# "question"
# "posed"
# "by"
# "the"
# "same"
# "character"
# ","
# "Jim"
# "Hacker"
# "."
# "Several"
# "episodes"
# "were"
# "adapted"
# "for"
# "BBC"
# "Radio"
# ","
# "and"
# "a"
# "stage"
# "play"
# "was"
# "produced"
# "in"
# "2010"
# ","
# "the"
# "latter"
# "leading"
# "to"
# "a"
# "new"
# "television"
# "series"
# "on"
# "UKTV"
# "Gold"
# "in"
# "2013"
# "."

# %%
for token in doc[:10]:
    print("{0}\t{1}\t{2}\t{3}\t{4}\t{5}\t{6}\t{7}".format(
        token.text,
        token.idx,
        token.lemma_,
        token.is_punct,
        token.is_space,
        token.shape_,
        token.pos_,
        token.tag_
    ))
# Out:
# The	0	the	False	False	Xxx	DET	DT
# sequel	4	sequel	False	False	xxxx	NOUN	NN
# ,	10	,	True	False	,	PUNCT	,
# Yes	12	yes	False	False	Xxx	INTJ	UH
# ,	15	,	True	False	,	PUNCT	,
# Prime	17	Prime	False	False	Xxxxx	PROPN	NNP
# Minister	23	Minister	False	False	Xxxxx	PROPN	NNP
# ,	31	,	True	False	,	PUNCT	,
# ran	33	run	False	False	xxx	VERB	VBD
# from	37	from	False	False	xxxx	ADP	IN

# %%
for ent in doc.ents:
    print(ent.text, ent.label_)
# Out:
# 1986 to 1988 DATE
# 38 CARDINAL
# one CARDINAL
# half an hour TIME
# Jim Hacker PERSON
# BBC Radio ORG
# 2010 DATE
# UKTV Gold ORG
# 2013 DATE

# %%
from spacy import displacy
displacy.render(doc, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">The sequel, Yes, Prime Minister, ran from
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1986 to 1988
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . In total there were
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     38
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  episodes, of which all but
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     one
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  lasted
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     half an hour
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
# . Almost all episodes ended with a variation of the title of the series spoken as the answer to a question posed by the same character,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Jim Hacker
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# . Several episodes were adapted for
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     BBC Radio
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , and a stage play was produced in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2010
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , the latter leading to a new television series on
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     UKTV Gold
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2013
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# .</div></span>

# %%
for sent in doc.sents:
    print(sent)
# Out:
# The sequel, Yes, Prime Minister, ran from 1986 to 1988.
# In total there were 38 episodes, of which all but one lasted half an hour.
# Almost all episodes ended with a variation of the title of the series spoken as the answer to a question posed by the same character, Jim Hacker.
# Several episodes were adapted for BBC Radio, and a stage play was produced in 2010, the latter leading to a new television series on UKTV Gold in 2013.

# %%
doc.sents

# %%
list(doc.sents)
# Out:
# [The sequel, Yes, Prime Minister, ran from 1986 to 1988.,
#  In total there were 38 episodes, of which all but one lasted half an hour.,
#  Almost all episodes ended with a variation of the title of the series spoken as the answer to a question posed by the same character, Jim Hacker.,
#  Several episodes were adapted for BBC Radio, and a stage play was produced in 2010, the latter leading to a new television series on UKTV Gold in 2013.]

# %%
newdoc = nlp(list(doc.sents)[0].text)

# %%
for token in newdoc:
    print("{0}/{1} <--{2}-- {3}/{4}".format(
        token.text, token.tag_, token.dep_, token.head.text, token.head.tag_))
# Out:
# The/DT <--det-- sequel/NN
# sequel/NN <--nsubj-- ran/VBD
# ,/, <--punct-- sequel/NN
# Yes/UH <--intj-- sequel/NN
# ,/, <--punct-- Yes/UH
# Prime/NNP <--compound-- Minister/NNP
# Minister/NNP <--appos-- sequel/NN
# ,/, <--punct-- sequel/NN
# ran/VBD <--ROOT-- ran/VBD
# from/IN <--prep-- ran/VBD
# 1986/CD <--pobj-- from/IN
# to/IN <--prep-- from/IN
# 1988/CD <--pobj-- to/IN
# ./. <--punct-- ran/VBD

# %%
displacy.render(newdoc, style='dep', jupyter=True, options={'distance': 90})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="60c86749ec7a4739b72af12bd1a5a5e6-0" class="displacy" width="950" height="272.0" direction="ltr" style="max-width: none; height: 272.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="182.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">The</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="182.0">
#     <tspan class="displacy-word" fill="currentColor" x="140">sequel,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="140">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="182.0">
#     <tspan class="displacy-word" fill="currentColor" x="230">Yes,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="230">INTJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="182.0">
#     <tspan class="displacy-word" fill="currentColor" x="320">Prime</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="320">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="182.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">Minister,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="182.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">ran</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="182.0">
#     <tspan class="displacy-word" fill="currentColor" x="590">from</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="590">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="182.0">
#     <tspan class="displacy-word" fill="currentColor" x="680">1986</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="680">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="182.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="182.0">
#     <tspan class="displacy-word" fill="currentColor" x="860">1988.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="860">NUM</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-60c86749ec7a4739b72af12bd1a5a5e6-0-0" stroke-width="2px" d="M70,137.0 C70,92.0 130.0,92.0 130.0,137.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-60c86749ec7a4739b72af12bd1a5a5e6-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,139.0 L62,127.0 78,127.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-60c86749ec7a4739b72af12bd1a5a5e6-0-1" stroke-width="2px" d="M160,137.0 C160,2.0 500.0,2.0 500.0,137.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-60c86749ec7a4739b72af12bd1a5a5e6-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M160,139.0 L152,127.0 168,127.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-60c86749ec7a4739b72af12bd1a5a5e6-0-2" stroke-width="2px" d="M160,137.0 C160,92.0 220.0,92.0 220.0,137.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-60c86749ec7a4739b72af12bd1a5a5e6-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">intj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M220.0,139.0 L228.0,127.0 212.0,127.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-60c86749ec7a4739b72af12bd1a5a5e6-0-3" stroke-width="2px" d="M340,137.0 C340,92.0 400.0,92.0 400.0,137.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-60c86749ec7a4739b72af12bd1a5a5e6-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M340,139.0 L332,127.0 348,127.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-60c86749ec7a4739b72af12bd1a5a5e6-0-4" stroke-width="2px" d="M160,137.0 C160,47.0 405.0,47.0 405.0,137.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-60c86749ec7a4739b72af12bd1a5a5e6-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">appos</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M405.0,139.0 L413.0,127.0 397.0,127.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-60c86749ec7a4739b72af12bd1a5a5e6-0-5" stroke-width="2px" d="M520,137.0 C520,92.0 580.0,92.0 580.0,137.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-60c86749ec7a4739b72af12bd1a5a5e6-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M580.0,139.0 L588.0,127.0 572.0,127.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-60c86749ec7a4739b72af12bd1a5a5e6-0-6" stroke-width="2px" d="M610,137.0 C610,92.0 670.0,92.0 670.0,137.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-60c86749ec7a4739b72af12bd1a5a5e6-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M
apple = nlp.vocab["apple"]
orange = nlp.vocab["orange"]

# %%
dog.similarity(cat)
# Out:
# 0.8220816850662231

# %%
dog.similarity(apple)
# Out:
# 0.22881005704402924

# %%
dog.similarity(orange)
# Out:
# 0.13284187018871307

# %%
apple.similarity(orange)
# Out:
# 0.6135187149047852

# %%
from scipy.spatial.distance import cosine

# %%
1 - cosine(dog.vector, cat.vector)
# Out:
# 0.8220816850662231

# %%
def vector_similarity(x, y):
    return 1 - cosine(x, y)

# %%
vector_similarity(dog.vector, apple.vector)
# Out:
# 0.22880998253822327

# %%
def make_guess_word(words):
    [first, second, third] = words
    return nlp.vocab[first].vector - nlp.vocab[second].vector + nlp.vocab[third].vector

# %%
def get_similar_word(words, scope=nlp.vocab):
    
    guess_word = make_guess_word(words)

    similarities = []

    for word in scope:
        if not word.has_vector:
            continue

        similarity = vector_similarity(guess_word, word.vector)
        similarities.append((word, similarity))


    similarities = sorted(similarities, key=lambda item: -item[1])
    print([word[0].text for word in similarities[:10]])

# %%
words = ["king", "queen", "woman"]

# %%
get_similar_word(words)
# Out:
# ['king', 'woman', 'that', 'who', 'he', 'those', '’cause', 'minister', 'she', "there's"]

# %%
words = ["Paris", "London", "England"]

# %%
get_similar_word(words)
# Out:
# ['Paris', 'England', 'Mont.', 'Mont', 'king', 'where', 'Colo', 'he', 'was', 'Mich']

# %%
import numpy as np

# %%
embedding = np.array([])

# %%
word_list = []

# %%
for token in doc:
    if not(token.is_punct) and not(token.text in word_list):
        word_list.append(token.text)

# %%
word_list
# Out:
# ['The',
#  'sequel',
#  'Yes',
#  'Prime',
#  'Minister',
#  'ran',
#  'from',
#  '1986',
#  'to',
#  '1988',
#  'In',
#  'total',
#  'there',
#  'were',
#  '38',
#  'episodes',
#  'of',
#  'which',
#  'all',
#  'but',
#  'one',
#  'lasted',
#  'half',
#  'an',
#  'hour',
#  'Almost',
#  'ended',
#  'with',
#  'a',
#  'variation',
#  'the',
#  'title',
#  'series',
#  'spoken',
#  'as',
#  'answer',
#  'question',
#  'posed',
#  'by',
#  'same',
#  'character',
#  'Jim',
#  'Hacker',
#  'Several',
#  'adapted',
#  'for',
#  'BBC',
#  'Radio',
#  'and',
#  'stage',
#  'play',
#  'was',
#  'produced',
#  'in',
#  '2010',
#  'latter',
#  'leading',
#  'new',
#  'television',
#  'on',
#  'UKTV',
#  'Gold',
#  '2013']

# %%
for word in word_list:
    embedding = np.append(embedding, nlp.vocab[word].vector)

# %%
embedding.shape
# Out:
# (18900,)

# %%
embedding = embedding.reshape(len(word_list), -1)

# %%
embedding.shape
# Out:
# (63, 300)

# %%
from sklearn.manifold import TSNE

# %%
tsne = TSNE()

# %%
low_dim_embedding = tsne.fit_transform(embedding)

# %%
import matplotlib.pyplot as plt
# %pylab inline
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib
# /srv/conda/envs/notebook/lib/python3.11/site-packages/IPython/core/magics/pylab.py:162: UserWarning: pylab import has clobbered these variables: ['text']
# `%matplotlib` prevents importing * from pylab and numpy
#   warn("pylab import has clobbered these variables: %s"  % clobbered +

# %%
def plot_with_labels(low_dim_embs, labels, filename='tsne.pdf'):
    assert low_dim_embs.shape[0] >= len(labels), "More labels than embeddings"
    plt.figure(figsize=(18, 18))  # in inches
    for i, label in enumerate(labels):
        x, y = low_dim_embs[i, :]
        plt.scatter(x, y)
        plt.annotate(label,
                 xy=(x, y),
                 xytext=(5, 2),
                 textcoords='offset points',
                 ha='right',
                 va='bottom')
    plt.savefig(filename)

# %%
plot_with_labels(low_dim_embedding, word_list)
